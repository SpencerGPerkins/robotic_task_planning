# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
# files
base = "../dataset/19.06_2/" 
vision = base + "vision/"
llm = base + "llm/"
labels = base + "labels/"
end_state = base +"end_sim_state/"

print( vision, llm, labels, end_state)
# Out:
# ../dataset/19.06_2/vision/ ../dataset/19.06_2/llm/ ../dataset/19.06_2/labels/ ../dataset/19.06_2/end_sim_state/

# %%
num_files_cycle = len([f for f in os.listdir(end_state) if os.path.isfile(os.path.join(end_state, f))])
print(num_files_cycle)
# Out:
# 81

# %%
end_sim_states_w = []
end_sim_states_t = []
for e in range(num_files_cycle):
    sim_id = e
    with open(f"{end_state}simulation_cycle_{e}.json", "r") as es_in:
        end_state_dict = json.load(es_in)
    end_sim_states_w.append(end_state_dict["wire"])
    end_sim_states_t.append(end_state_dict["terminal"])

len(end_sim_states_w) == len(end_sim_states_t)
# Out:
# True

# %%
num_files_vision= len([f for f in os.listdir(vision) if os.path.isfile(os.path.join(vision, f))])
num_files_labels= len([f for f in os.listdir(labels) if os.path.isfile(os.path.join(labels, f))])
print(f"Number of vision Files: {num_files_vision}, Number of label files: {num_files_labels}")
to_dataset_samples = []
discard_samples = []
distance_thresh = 0.1
held_zub = 0.1
held_zlb = 0.04
# Out:
# Number of vision Files: 175, Number of label files: 175

# %%
def euclidean_distance(pos1, pos2):
    return np.linalg.norm(np.array(pos1) - np.array(pos2))

# %%
previous_sim_id = 0
iter_counter = 0
for v in range(num_files_vision):
    with open(f"{vision}sample_{v}.json", "r") as vision_in:
        vision_file = json.load(vision_in)
    wires = vision_file["wires"]

    # Checks the z coordinate for on table wires
    for wire in wires:
        if wire["state"] == "on_table" and wire["coordinates"][2] > 0.01 or wire["coordinates"][2] < 0.0:
            discard_samples.append([v, current_sim_id])
    terminals = vision_file["terminals"]
    current_sim_id = vision_file["metadata"]["simulation_id"] # Save Sim cycle ID from vision file
    with open(f"{labels}sample_{v}.json", "r") as label_in:
        label_file = json.load(label_in)
    target_wire_id = label_file["target_wire"]["ID"]
    target_terminal = label_file["target_terminal"]["name"]
    target_wire_coords = wires[target_wire_id]["coordinates"]
    target_terminal_coords = terminals[target_terminal]["coordinates"]

    # Checks the distance wire-terminal for "inserted" wire
    if label_file["correct_action"] == "lock":
        distance_wire_terminal = euclidean_distance(target_wire_coords, target_terminal_coords)
        if distance_wire_terminal <= distance_thresh:
            continue
        else:
            if [v, current_sim_id] not in discard_samples:
                discard_samples.append([v, current_sim_id])

    # Checks the z coordinate for "held" wire
    elif label_file["correct_action"] == "insert":
        if target_wire_coords[2] > held_zub or target_wire_coords[2] < held_zlb and [v, current_sim_id] not in discard_samples:
            print(f"\n\nCHeck this sample: z {v}")
            discard_samples.append([v, current_sim_id])
        else:
            continue
print(discard_samples)
print(len(discard_samples))
print(f"Percentage of usable data samples: {((num_files_vision-len(discard_samples)) * 100) / num_files_vision:.2f}%")
# Out:
# CHeck this sample: z 3
#
#
# CHeck this sample: z 5
#
#
# CHeck this sample: z 10
#
#
# CHeck this sample: z 13
#
#
# CHeck this sample: z 22
#
#
# CHeck this sample: z 47
#
#
# CHeck this sample: z 50
#
#
# CHeck this sample: z 62
#
#
# CHeck this sample: z 66
#
#
# CHeck this sample: z 69
#
#
# CHeck this sample: z 81
#
#
# CHeck this sample: z 89
#
#
# CHeck this sample: z 101
#
#
# CHeck this sample: z 105
#
#
# CHeck this sample: z 115
#
#
# CHeck this sample: z 129
#
#
# CHeck this sample: z 141
#
#
# CHeck this sample: z 143
#
#
# CHeck this sample: z 151
#
#
# CHeck this sample: z 159
#
#
# CHeck this sample: z 164
# [[3, 1], [5, 2], [10, 5], [13, 7], [14, 7], [22, 10], [23, 10], [23, 10], [24, 11], [25, 11], [36, 15], [37, 16], [42, 18], [46, 21], [47, 22], [50, 24], [51, 24], [62, 28], [63, 28], [64, 28], [66, 30], [67, 30], [69, 31], [70, 31], [71, 31], [72, 32], [78, 34], [81, 37], [82, 37], [83, 38], [84, 38], [85, 38], [86, 39], [87, 39], [89, 40], [94, 42], [95, 43], [96, 43], [101, 45], [102, 45], [103, 45], [103, 45], [103, 45], [105, 47], [107, 48], [108, 49], [109, 49], [114, 51], [115, 52], [116, 52], [116, 52], [117, 53], [118, 53], [119, 53], [120, 54], [127, 57], [129, 59], [130, 59], [131, 60], [132, 60], [133, 60], [134, 61], [135, 61], [141, 64], [143, 65], [144, 65], [147, 66], [151, 69], [152, 69], [153, 70], [154, 70], [155, 70], [159, 73], [164, 76], [165, 76], [168, 77], [169, 78], [170, 78], [171, 79]]
# 79
# Percentage of usable data samples: 54.86%

# %%
sample_ids = []
cycle_ids = []
for sample in discard_samples:
    sample_ids.append(sample[0])
    cycle_ids.append(sample[1])
print(len(sample_ids), len(cycle_ids))
# Out:
# 79 79

# %%
import shutil 
source_directory_base = "../dataset/19.06_2/"
destination_directory_base = "../dataset/19.06_2_cleantest/"
parent_dirs = ["vision/", "llm/", "labels/"]
for parent_d in parent_dirs:
    source_directory = source_directory_base + parent_d
    destination_directory = destination_directory_base + parent_d
    counter = 0
    for f in range(num_files_vision):
        if f not in sample_ids:
            old_file_name = f"sample_{f}.json"
            new_file_name = f"sample_{counter}.json"
            counter += 1
            source_path = os.path.join(source_directory, old_file_name)
            destination_path = os.path.join(destination_directory, new_file_name)
            try:
                shutil.copy(source_path, destination_path)
                print(f"File '{old_file_name}' copied successfully from '{source_directory}' to '{destination_directory}'.")
            except FileNotFoundError:
                print(f"Error: Source file '{source_path}' not found.")
            except Exception as e:
                print(f"An error occurred: {e}")
# Out:
# File 'sample_0.json' copied successfully from '../dataset/19.06_2/vision/' to '../dataset/19.06_2_cleantest/vision/'.
# File 'sample_1.json' copied successfully from '../dataset/19.06_2/vision/' to '../dataset/19.06_2_cleantest/vision/'.
# File 'sample_2.json' copied successfully from '../dataset/19.06_2/vision/' to '../dataset/19.06_2_cleantest/vision/'.
# File 'sample_4.json' copied successfully from '../dataset/19.06_2/vision/' to '../dataset/19.06_2_cleantest/vision/'.
# File 'sample