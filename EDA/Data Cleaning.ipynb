# %%
import json
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
# files
base = "../dataset/0701/" 
vision = base + "vision/"
llm = base + "llm/"
labels = base + "labels/"
end_state = base +"end_sim_state/"

print( vision, llm, labels, end_state)
# Out:
# ../dataset/0701/vision/ ../dataset/0701/llm/ ../dataset/0701/labels/ ../dataset/0701/end_sim_state/

# %%
num_files_cycle = len([f for f in os.listdir(end_state) if os.path.isfile(os.path.join(end_state, f))])
print(num_files_cycle)
# Out:
# 193

# %%
num_files_vision= len([f for f in os.listdir(vision) if os.path.isfile(os.path.join(vision, f))])
num_files_labels= len([f for f in os.listdir(labels) if os.path.isfile(os.path.join(labels, f))])
print(f"Number of vision Files: {num_files_vision}, Number of label files: {num_files_labels}")
to_dataset_samples = []
discard_samples = []
distance_thresh = 0.05
held_zub = 0.1
held_zlb = 0.02
# Out:
# Number of vision Files: 408, Number of label files: 408

# %%
def euclidean_distance(pos1, pos2):
    return np.linalg.norm(np.array(pos1) - np.array(pos2))

# %%
previous_sim_id = 0
iter_counter = 0

clean_dataset_action_counts = {
    "pick": 0,
    "insert": 0,
    "lock": 0,
    "putdown": 0
}
for v in range(num_files_vision):
    with open(f"{vision}sample_{v}.json", "r") as vision_in:
        vision_file = json.load(vision_in)
    wires = vision_file["wires"]

    # Checks the z coordinate for on table wires
    for wire in wires:
        if wire["state"] == "on_table" and wire["position"][2] > 0.01 or wire["position"][2] < 0.0:
            discard_samples.append([v, current_sim_id])
        else:
            clean_dataset_action_counts["pick"] += 1
    terminals = vision_file["terminals"]
    current_sim_id = vision_file["metadata"]["simulation_id"] # Save Sim cycle ID from vision file
    with open(f"{labels}sample_{v}.json", "r") as label_in:
        label_file = json.load(label_in)
    target_wire_id = label_file["target_wire"]["ID"]
    target_terminal = label_file["target_terminal"]["name"]
    target_wire_coords = wires[target_wire_id]["position"]
    target_terminal_coords = terminals[target_terminal]["position"]

    # Checks the distance wire-terminal for "inserted" wire
    if label_file["correct_action"] == "lock":
        distance_wire_terminal = euclidean_distance(target_wire_coords, target_terminal_coords)
        if distance_wire_terminal <= distance_thresh and target_wire_coords[2] < held_zlb:
            clean_dataset_action_counts["lock"] += 1
            continue
        else:
            if [v, current_sim_id] not in discard_samples:
                discard_samples.append([v, current_sim_id])

    # Checks the z coordinate for "held" wire
    elif label_file["correct_action"] == "insert":
        if target_wire_coords[2] > held_zub or target_wire_coords[2] < held_zlb and [v, current_sim_id] not in discard_samples:
            print(f"\n\nCHeck this sample: z {v}")
            discard_samples.append([v, current_sim_id])
        else:
            clean_dataset_action_counts["insert"] += 1
            continue
print(discard_samples)
print(len(discard_samples))
print(f"Percentage of usable data samples: {((num_files_vision-len(discard_samples)) * 100) / num_files_vision:.2f}%")
# Out:
# CHeck this sample: z 15
#
#
# CHeck this sample: z 62
#
#
# CHeck this sample: z 114
#
#
# CHeck this sample: z 173
#
#
# CHeck this sample: z 243
#
#
# CHeck this sample: z 321
#
#
# CHeck this sample: z 353
#
#
# CHeck this sample: z 378
#
#
# CHeck this sample: z 388
# [[9, 9], [10, 10], [11, 10], [12, 11], [13, 11], [14, 11], [15, 12], [16, 12], [24, 15], [24, 15], [24, 15], [25, 16], [25, 16], [32, 19], [33, 20], [40, 24], [41, 25], [42, 25], [62, 33], [63, 33], [66, 34], [68, 36], [69, 37], [88, 44], [88, 44], [88, 44], [89, 45], [89, 45], [89, 45], [90, 45], [90, 45], [90, 45], [91, 45], [95, 48], [96, 49], [97, 49], [104, 52], [104, 52], [105, 53], [105, 53], [106, 53], [106, 53], [114, 57], [138, 68], [139, 69], [148, 73], [158, 78], [158, 78], [159, 79], [159, 79], [173, 85], [174, 85], [177, 86], [178, 86], [179, 87], [180, 88], [181, 88], [181, 88], [182, 89], [182, 89], [183, 89], [183, 89], [188, 91], [189, 92], [203, 99], [203, 99], [204, 100], [205, 100], [209, 101], [210, 102], [211, 102], [224, 110], [225, 111], [226, 111], [230, 112], [230, 112], [230, 112], [231, 113], [231, 113], [231, 113], [235, 114], [236, 115], [237, 115], [238, 115], [239, 116], [240, 116], [241, 117], [242, 117], [243, 118], [244, 118], [245, 119], [246, 120], [247, 120], [250, 121], [251, 122], [252, 122], [253, 122], [254, 123], [254, 123], [255, 124], [256, 124], [266, 128], [266, 128], [267, 129], [268, 129], [275, 132], [275, 132], [276, 133], [277, 134], [282, 136], [283, 137], [284, 137], [297, 144], [298, 145], [299, 145], [302, 146], [307, 148], [308, 149], [317, 152], [321, 155], [325, 157], [326, 158], [334, 161], [334, 161], [352, 170], [353, 171], [354, 171], [358, 172], [359, 173], [360, 173], [369, 178], [378, 184], [379, 184], [380, 185], [387, 188], [388, 189], [396, 192], [400, 194], [401, 195], [403, 196], [404, 197], [405, 198], [406, 198], [407, 199]]
# 144
# Percentage of usable data samples: 64.71%

# %%
sample_ids = []
cycle_ids = []
for sample in discard_samples:
    sample_ids.append(sample[0])
    cycle_ids.append(sample[1])
print(len(sample_ids), len(cycle_ids))
# Out:
# 144 144

# %%
import shutil 
source_directory_base = "../dataset/0701/"
destination_directory_base = "../dataset/0701_clean/"
parent_dirs = ["vision/", "llm/", "labels/"]
for parent_d in parent_dirs:
    source_directory = source_directory_base + parent_d
    destination_directory = destination_directory_base + parent_d
    counter = 0
    for f in range(num_files_vision):
        if f not in sample_ids:
            old_file_name = f"sample_{f}.json"
            new_file_name = f"sample_{counter}.json"
            counter += 1
            source_path = os.path.join(source_directory, old_file_name)
            destination_path = os.path.join(destination_directory, new_file_name)
            try:
                shutil.copy(source_path, destination_path)
                print(f"File '{old_file_name}' copied successfully from '{source_directory}' to '{destination_directory}'.")
            except FileNotFoundError:
                print(f"Error: Source file '{source_path}' not found.")
            except Exception as e:
                print(f"An error occurred: {e}")
# Out:
# File 'sample_0.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_1.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_2.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_3.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_4.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_5.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_6.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_7.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_8.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_17.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_18.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_19.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_20.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_21.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_22.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_23.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_26.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_27.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_28.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_29.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_30.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_31.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_34.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_35.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_36.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_37.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_38.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_39.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_43.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_44.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_45.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_46.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_47.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_48.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_49.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_50.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_51.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_52.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_53.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_54.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_55.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_56.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_57.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_58.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_59.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_60.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_61.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_64.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_65.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_67.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_70.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_71.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_72.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_73.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_74.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_75.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_76.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_77.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_78.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_79.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_80.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_81.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_82.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_83.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_84.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_85.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_86.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_87.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_92.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_93.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_94.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_98.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_99.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_100.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_101.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_102.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_103.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_107.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_108.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_109.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_110.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_111.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_112.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_113.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_115.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_116.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_117.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_118.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_119.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_120.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_121.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_122.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_123.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_124.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_125.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_126.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_127.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_128.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_129.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_130.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_131.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_132.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_133.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_134.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_135.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_136.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_137.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_140.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_141.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_142.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_143.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_144.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_145.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_146.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_147.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_149.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_150.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_151.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_152.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_153.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_154.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_155.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_156.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_157.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_160.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_161.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_162.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_163.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_164.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_165.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_166.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_167.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_168.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_169.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_170.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_171.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_172.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_175.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_176.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_184.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_185.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_186.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_187.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_190.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_191.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_192.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_193.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_194.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_195.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_196.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_197.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_198.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_199.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_200.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_201.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_202.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_206.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_207.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_208.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_212.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_213.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_214.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_215.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_216.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_217.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_218.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_219.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_220.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_221.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_222.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_223.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_227.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_228.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_229.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_232.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_233.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_234.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_248.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_249.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_257.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_258.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_259.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_260.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_261.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_262.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_263.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_264.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_265.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_269.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_270.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_271.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_272.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_273.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_274.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_278.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_279.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_280.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_281.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_285.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_286.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_287.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_288.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_289.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_290.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_291.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_292.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_293.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_294.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_295.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_296.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_300.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_301.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_303.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_304.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_305.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_306.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_309.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_310.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_311.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_312.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_313.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_314.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_315.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_316.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_318.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_319.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_320.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_322.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_323.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_324.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_327.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_328.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_329.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_330.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_331.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_332.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_333.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_335.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_336.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_337.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_338.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_339.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_340.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_341.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_342.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_343.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_344.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_345.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_346.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_347.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_348.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_349.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_350.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_351.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_355.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_356.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_357.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_361.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_362.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_363.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_364.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_365.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_366.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_367.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_368.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_370.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_371.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_372.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_373.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_374.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_375.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_376.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_377.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_381.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_382.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_383.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_384.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_385.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_386.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_389.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_390.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_391.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_392.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_393.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_394.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_395.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_397.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_398.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_399.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_402.json' copied successfully from '../dataset/0701/vision/' to '../dataset/0701_clean/vision/'.
# File 'sample_0.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_1.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_2.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_3.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_4.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_5.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_6.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_7.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_8.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_17.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_18.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_19.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_20.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_21.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_22.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_23.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_26.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_27.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_28.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_29.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_30.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_31.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_34.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_35.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_36.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_37.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_38.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_39.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_43.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_44.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_45.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_46.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_47.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_48.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_49.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_50.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_51.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_52.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_53.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_54.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_55.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_56.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_57.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_58.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_59.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_60.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_61.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_64.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_65.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_67.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_70.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_71.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_72.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_73.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_74.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_75.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_76.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_77.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_78.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_79.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_80.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_81.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_82.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_83.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_84.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_85.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_86.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_87.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_92.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_93.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_94.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_98.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_99.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_100.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_101.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_102.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_103.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_107.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_108.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_109.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_110.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_111.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_112.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_113.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_115.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_116.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_117.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_118.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_119.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_120.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_121.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_122.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_123.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_124.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_125.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_126.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_127.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_128.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_129.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_130.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_131.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_132.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_133.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_134.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_135.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_136.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_137.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_140.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_141.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_142.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_143.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_144.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_145.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_146.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_147.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_149.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_150.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_151.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_152.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_153.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_154.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_155.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_156.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_157.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_160.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_161.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_162.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_163.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_164.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_165.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_166.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_167.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_168.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_169.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_170.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_171.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_172.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_175.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_176.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_184.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_185.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_186.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_187.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_190.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_191.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_192.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_193.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_194.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_195.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_196.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_197.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_198.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_199.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_200.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_201.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# File 'sample_202.json' copied successfully from '../dataset/0701/llm/' to '../dataset/0701_clean/llm/'.
# ...
# File 'sample_192.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_193.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_194.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_195.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_196.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_197.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_198.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_199.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_200.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_201.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_202.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_206.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_207.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_208.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_212.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_213.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_214.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_215.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_216.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_217.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_218.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_219.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_220.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_221.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_222.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_223.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_227.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_228.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_229.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_232.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_233.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_234.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_248.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_249.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_257.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_258.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_259.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_260.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_261.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_262.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_263.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_264.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_265.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_269.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_270.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_271.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_272.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_273.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_274.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_278.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_279.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_280.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_281.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_285.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_286.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_287.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_288.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_289.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_290.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_291.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_292.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_293.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_294.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_295.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_296.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_300.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_301.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_303.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_304.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_305.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_306.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_309.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_310.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_311.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_312.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_313.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_314.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_315.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_316.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_318.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_319.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_320.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_322.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_323.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_324.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_327.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_328.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_329.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_330.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_331.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_332.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_333.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_335.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_336.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_337.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_338.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_339.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_340.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_341.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_342.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_343.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_344.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_345.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_346.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_347.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_348.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_349.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_350.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_351.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_355.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_356.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_357.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_361.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_362.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_363.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_364.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_365.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_366.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_367.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_368.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_370.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_371.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_372.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_373.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_374.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_375.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_376.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_377.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_381.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_382.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_383.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_384.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_385.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_386.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_389.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_390.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_391.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_392.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_393.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_394.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_395.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_397.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_398.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_399.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.
# File 'sample_402.json' copied successfully from '../dataset/0701/labels/' to '../dataset/0701_clean/labels/'.

# %%
directory = destination_directory_base + parent_dirs[0]
num_files_clean = len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])
num_files_clean
# Out:
# 290

# %%
with open("../dataset/0701_clean/meta/action_counts.json", "w") as write_file:
    json.dump(clean_dataset_action_counts, write_file)
